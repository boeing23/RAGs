# %%
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.5/633.5 kB 22.2 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-nomic
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 37.6 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 40.0 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for nomic: filename=nomic-3.4.1-py3-none-any.whl size=49942 sha256=7ecc7a7379bb7c24b089980984039826a8149111b48b3e9e658436bd1f1fba62
#   Stored in directory: /Users/boeing23/Library/Caches/pip/wheels/4e/e9/8d/109127342e027d910586035b03f72e732e4d95f6a7144db92c
# Successfully built nomic
# ...

# %%
ollama pull llama3.2:3b-instruct-fp16
# Out:
#   Cell In[6], line 1
#     ollama pull llama3.2:3b-instruct-fp16
#                          ^
# SyntaxError: invalid decimal literal
